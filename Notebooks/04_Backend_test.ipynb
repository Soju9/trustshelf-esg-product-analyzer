# %%
import sys
sys.path.insert(0, "../")

import app_backend
print(app_backend.__file__)
# Out:
# c:\Users\nicom\Desktop\WBS\Final Project\Notebooks\..\app_backend.py

# %%
import importlib
importlib.reload(app_backend)
# Out:
# <module 'app_backend' from 'c:\\Users\\nicom\\Desktop\\WBS\\Final Project\\Notebooks\\..\\app_backend.py'>

# %%
label_mapping, confidence_mapping, eco_baselines = app_backend.load_scoring_resources()

label_mapping.columns.tolist()
# Out:
# ['indx',
#  'database',
#  'label_keyword',
#  'matched_label',
#  'category',
#  'score_type',
#  'environmental',
#  'social',
#  'governance',
#  'ethic',
#  'score_group',
#  'reason',
#  'note',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'label_keyword_clean']

# %%
results = app_backend.search_product("Nutella", page_size=5)
results.head()
# Out:
#   source retrieval_method search_query        barcode         product_name  \
# 0   food           search      Nutella  3017620425035              Nutella
# 1   food           search      Nutella  8000500426494  Nutella Plant-Based
# 2   food           search      Nutella       80176800              Nutella
#
#                     generic_name             brand  \
# 0  Pâte à tartiner aux noisettes           nutella
# 1     Hazelnut and cocoa spread.  Ferrero, nutella
# 2               Nuss-Nugat-Creme  Ferrero, nutella
#
#                                           categories  \
# 0  pates-a-tartiner-au-chocolat, pates-a-tartiner...
# 1                        Cocoa and hazelnuts spreads
# 2                Snacks, Cocoa and hazelnuts spreads
#
#                                        category_tags  \
# 0  [en:pates-a-tartiner-au-chocolat, en:pates-a-t...
# 1  [en:breakfasts, en:spreads, en:sweet-spreads, ...
# 2  [en:snacks, en:breakfasts, en:spreads, en:swee...
#
# ...
